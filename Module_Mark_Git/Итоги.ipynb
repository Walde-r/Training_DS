# %% [markdown]
# ⭐ В этом модуле мы подробнее разобрали инструменты, которые помогают в оформлении портфолио — язык разметки Markdown и Git.
#
# Во второй части модуля мы поговорили о процессе работы над проектом с точки зрения инструментов Git и GitHub:
#
# - разобрали, что такое коммит, как он строится и производится;
# - обсудили, как создавать правильные коммиты;
# - поговорили о ветвлении и изучили несколько самых популярных методологий ветвления проектов, использование которых зависит от
# - условий и принципов работы над проектом;
# - рассмотрели, что такое форк и когда он может вам пригодиться.
#
# Владение этими умениями повышает ваш уровень как дата-сайентиста и пригодится в будущем при устройстве на работу.
#
# Закрепить полученные знания и отработать навыки вы сможете уже в следующем модуле, когда будете выполнять свой первый Data Science-проект. Не забывайте о принципах и рекомендациях, которые мы обсуждали, и в последующих проектах.
#
# Также предлагаем вам познакомиться с дополнительной литературой:
# - [Краткое руководство по Markdown](https://codepen.io/paulradzkov/pen/ZGoLgr).
# - [Учебник по Git](https://githowto.com/ru).
# - [Работа с Git. Задания и решения](https://smartiqa.ru/courses/git/answer-key).
