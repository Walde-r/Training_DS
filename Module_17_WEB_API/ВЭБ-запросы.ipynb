# %% [markdown]
# > Процесс получения/извлечения информации с веб-ресурсов в интернете называется `web-scraping` (рус. веб-скрейпинг,
# > веб-скрапинг).
# > Веб-скрапинг может быть проделан вручную пользователем компьютера, однако этот термин обычно связывают с автоматизированными
# > процессами, реализованными с помощью кода.
#
# Какие данные можно извлечь в процессе веб-скрапинга?
#
# - цены на товары конкурентов для оптимизации своей стратегии ценообразования;
# - сообщения в социальных медиа, по которым можно отслеживать тренды в той или иной области;
# - отзывы о товарах/услугах компании на различных площадках, которые можно впоследствии анализировать;
# - контактные данные пользователей соцсетей или форумов для дальнейшего взаимодействия с этими пользователями;
# и т.д.
#
# Для того чтобы веб-скрапинг был возможен, необходимо подключение компьютера, который будет задействован в этом процессе, к сети Интернет.
#
# > Интернет — это глобальная информационная сеть, которая позволяет компьютерам по всему миру обмениваться информацией. Один
# > компьютер (называемый клиентом) отправляет запрос в определённом формате другому компьютеру (называемому сервером) и получает
# > ответ (текст, изображение, видео и т. д.).
#
#
# <center> <img src='Module_17_WEB_API/img/Client-server-model.png'> </center>
#
# Клиент и сервер взаимодействуют между собой, обмениваясь одиночными сообщениями (не потоком данных) посредством сетевых протоколов, которые формализуют общение между ними. В настоящее время повсеместно используемый протокол в интернете, позволяющий клиенту получать различные ресурсы (например, HTML-документы), — это протокол `HTTP`.
#
# <table>
#     <td>Запрос, отправляемый клиентом с использованием протокола HTTP, состоит из нескольких элементов:
#         <ul>
#           <li>адрес, по которому идёт обращение (например, `www.google.com`);</li>
#           <li>техническая информация, например метод запроса;</li>
#           <li>дополнительные данные, например если загружается (передаётся) изображение.</li>
#         </ul>
#         <b>Адрес — это URL, Uniform Resource Locator (с англ. Унифицированный Указатель Ресурса)</b>.
#     </td>
#     <td>Ответ, в свою очередь, состоит из следующих элементов:
#         <ul>
#             <li>код статуса ответа: например, 200 («успешно»), 404 («не найден») и т. д. (более полный список кодов статуса ответа можете посмотреть, перейдя по <a href="[URL](https://ru.wikipedia.org/wiki/Список_кодов_состояния_HTTP)">ссылке</a>;</li>
#             <li>текст в запрошенном формате (HTML, XML, JSON и т. д.) или мультимедийные файлы;</li>
#             <li>прочая техническая информация.</li>
#         </ul>
#     </td>
# </table>
#
# #### Методы запросов в протоколе HTTP
#
# Для того чтобы указать серверу на то, какое действие мы хотим произвести с ресурсом, в протоколе HTTP используются так называемые **методы**. В HTTP существует несколько методов, которые описывают действия с ресурсами. Чаще всего используются `GET` и `POST`.
#
# **GET — получение ресурса**
#
# Метод `GET` запрашивает информацию из указанного источника и не может влиять на его содержимое. Запрос доступен для кэширования данных (то есть для сохранения, восстановления и дальнейшего использования) и добавления в закладки. Длина запроса ограничена (максимальная длина — 2048 символов).
#
# Пример `GET-запроса`, отправляемого через адресную строку браузера:
#
# > http://site.ru/page.php?name=dima&age=27
#
# **POST — создание ресурса**
#
# Метод `POST` используется для отправки данных, которые могут оказывать влияние на содержимое ресурса. В отличие от метода `GET`, запросы `POST` не могут быть кэшированы, они не остаются в истории браузера и их нельзя добавить в закладки. Длина запроса `POST` не ограничивается.
#
# Пример POST-запроса, отправляемого через форму запроса:
#
# > POST / HTTP/1.0\r\n<br>
# > Host: www.site.ru\r\n<br>
# > Referer: http://www.site.ru/index.html\r\<br>
# > Cookie: income=1\r\n<br>
# > Content-Type: application/x-www-form-urlencoded\r\n<br>
# > Content-Length: 35\r\n<br>
# > \r\n<br>
# > login=Dima&password=12345<br>
#
# ***ДОПОЛНИТЕЛЬНО***
#
# Подробнее про методы HTTP можете прочитать, перейдя по этой [ссылке](https://developer.mozilla.org/ru/docs/Web/HTTP/Methods).
#
# Эти знания пригодятся нам с вами в дальнейшем при подготовке запросов на получение информации от сервера и анализе полученных от него ответов.
#
# #### Библиотека requests
#
# ✍ В стандартной библиотеке `Python` для отправки веб-запросов существует функция `urllib2`, но большинство разработчиков используют стороннюю библиотеку `requests` (c англ. запросы), потому что её работа более стабильна, а созданный с её помощью код получается проще. Поэтому мы будем работать с библиотекой `requests`, а `urllib2` рассматривать не будем.
#
# Познакомимся с библиотекой `requests`, решив простую задачу — получить значения курсов валют. Курс валют — полезная и регулярно обновляемая информация, но каждый раз в ручном режиме получать информацию о курсе интересующей валюты трудоёмко.
#
# > Разработаем код, так называемый **скрипт** (англ. script, рус. сценарий), — небольшую программу, которая содержит
# > последовательность действий для автоматического выполнения задачи.
#
# С помощью скрипта мы будем в удобном виде выгружать информацию по курсам валют с заранее выбранного сайта.
#
# > Один из сайтов в интернете, на котором информация о курсах валют дублирует информацию с сайта [Центрального Банка России](https://www.cbr.ru/), —
# > ресурс [Курсы валют ЦБ РФ в XML и JSON](https://www.cbr-xml-daily.ru/). На данном ресурсе информация о курсах валют представлена в разных форматах, в том числе
# > и в структурированном JSON-формате, методы работы с которым мы изучили в одном из предыдущих модулей.
#
# Перед началом работы библиотеку `requests` потребуется установить. Например, в Jupyter Notebook это делается с помощью такой команды:
#
# ```python
# # Устанавливаем библиотеку requests
# !pip install requests
# ```
#
# Как только библиотека установлена, импортируем её и отправим наш первый запрос к ресурсу [Курсы валют ЦБ РФ в XML и JSON](https://www.cbr-xml-daily.ru/daily_json.js). Используем метод `get()` из библиотеки `requests`, передав ему соответствующий URL —  `https://www.cbr-xml-daily.ru/daily_json.js`:

# %%
import requests # Импортируем библиотеку requests
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response

print(response) # Выводим значение response на экран как объект
# Out:
# <Response [200]>

# %% [markdown]
# Мы получили объект ответа `Response`, который содержит всю нужную нам информацию.
#
# По умолчанию в квадратных скобках на экран выводится код статуса ответа.
#
# - **200** — то есть запрос был корректным и сервер отдал нам нужную информацию.
# - **404** означало бы, что страница по указанному адресу не найдена,
# - **403** — что синтаксис GET-запроса неверный.
#
# Код ответа в виде числовой переменной можно получить с помощью метода `status_code`:

# %%
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# 200

# %% [markdown]
# #### Работаем с ответом
#
# Мы сделали запрос и получили корректный ответ (код статуса — 200). Дальнейшую работу производим с результатом запроса к ресурсу Курсы валют ЦБ РФ в XML и JSON.
#
# Как получить доступ ко всей информации, которую содержит ответ?
#
# Текст ответа хранится в атрибуте text. Выведем значение атрибута на экран и посмотрим на его содержимое:

# %%
print(response.text)
# Out:
# {
#     "Date": "2025-05-23T11:30:00+03:00",
#     "PreviousDate": "2025-05-22T11:30:00+03:00",
#     "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2025\/05\/22\/daily_json.js",
#     "Timestamp": "2025-05-22T20:00:00+03:00",
#     "Valute": {
#         "AUD": {
#             "ID": "R01010",
#             "NumCode": "036",
#             "CharCode": "AUD",
#             "Nominal": 1,
#             "Name": "Австралийский доллар",
#             "Value": 51.4136,
#             "Previous": 51.4566
#         },
#         "AZN": {
#             "ID": "R01020A",
#             "NumCode": "944",
#             "CharCode": "AZN",
#             "Nominal": 1,
#             "Name": "Азербайджанский манат",
#             "Value": 46.9034,
#             "Previous": 46.9135
#         },
#         "GBP": {
#             "ID": "R01035",
#             "NumCode": "826",
#             "CharCode": "GBP",
#             "Nominal": 1,
#             "Name": "Фунт стерлингов",
#             "Value": 107.1409,
#             "Previous": 106.6218
#         },
#         "AMD": {
#             "ID": "R01060",
#             "NumCode": "051",
#             "CharCode": "AMD",
#             "Nominal": 100,
#             "Name": "Армянских драмов",
#             "Value": 20.7407,
#             "Previous": 20.7118
#         },
#         "BYN": {
#             "ID": "R01090B",
#             "NumCode": "933",
#             "CharCode": "BYN",
#             "Nominal": 1,
#             "Name": "Белорусский рубль",
#             "Value": 26.5449,
#             "Previous": 26.5525
#         },
#         "BGN": {
#             "ID": "R01100",
#             "NumCode": "975",
#             "CharCode": "BGN",
#             "Nominal": 1,
#             "Name": "Болгарский лев",
#             "Value": 46.1538,
#             "Previous": 45.8374
#         },
#         "BRL": {
#             "ID": "R01115",
#             "NumCode": "986",
#             "CharCode": "BRL",
#             "Nominal": 1,
#             "Name": "Бразильский реал",
#             "Value": 14.0955,
#             "Previous": 14.0864
#         },
#         "HUF": {
#             "ID": "R01135",
#             "NumCode": "348",
#             "CharCode": "HUF",
#             "Nominal": 100,
#             "Name": "Форинтов",
#             "Value": 22.3506,
#             "Previous": 22.4303
#         },
#         "VND": {
#             "ID": "R01150",
#             "NumCode": "704",
#             "CharCode": "VND",
#             "Nominal": 10000,
#             "Name": "Донгов",
#             "Value": 31.9518,
#             "Previous": 31.9498
#         },
#         "HKD": {
#             "ID": "R01200",
#             "NumCode": "344",
#             "CharCode": "HKD",
#             "Nominal": 1,
#             "Name": "Гонконгский доллар",
#             "Value": 10.2068,
#             "Previous": 10.2025
#         },
#         "GEL": {
#             "ID": "R01210",
#             "NumCode": "981",
#             "CharCode": "GEL",
#             "Nominal": 1,
#             "Name": "Лари",
#             "Value": 29.1038,
#             "Previous": 29.1059
#         },
#         "DKK": {
#             "ID": "R01215",
#             "NumCode": "208",
#             "CharCode": "DKK",
#             "Nominal": 1,
#             "Name": "Датская крона",
#             "Value": 12.1017,
#             "Previous": 12.0182
#         },
#         "AED": {
#             "ID": "R01230",
#             "NumCode": "784",
#             "CharCode": "AED",
#             "Nominal": 1,
#             "Name": "Дирхам ОАЭ",
#             "Value": 21.7116,
#             "Previous": 21.7163
#         },
#         "USD": {
#             "ID": "R01235",
#             "NumCode": "840",
#             "CharCode": "USD",
#             "Nominal": 1,
#             "Name": "Доллар США",
#             "Value": 79.7357,
#             "Previous": 79.753
#         },
#         "EUR": {
#             "ID": "R01239",
#             "NumCode": "978",
#             "CharCode": "EUR",
#             "Nominal": 1,
#             "Name": "Евро",
#             "Value": 90.2004,
#             "Previous": 91.299
#         },
#         "EGP": {
#             "ID": "R01240",
#             "NumCode": "818",
#             "CharCode": "EGP",
#             "Nominal": 10,
#             "Name": "Египетских фунтов",
#             "Value": 15.9785,
#             "Previous": 15.9951
#         },
#         "INR": {
#             "ID": "R01270",
#             "NumCode": "356",
#             "CharCode": "INR",
#             "Nominal": 100,
#             "Name": "Индийских рупий",
#             "Value": 93.0782,
#             "Previous": 93.2188
#         },
#         "IDR": {
#             "ID": "R01280",
#             "NumCode": "360",
#             "CharCode": "IDR",
#             "Nominal": 10000,
#             "Name": "Рупий",
#             "Value": 48.5808,
#             "Previous": 48.6121
#         },
#         "KZT": {
#             "ID": "R01335",
#             "NumCode": "398",
#             "CharCode": "KZT",
#             "Nominal": 100,
#             "Name": "Тенге",
#             "Value": 15.6164,
#             "Previous": 15.5892
#         },
#         "CAD": {
#             "ID": "R01350",
#             "NumCode": "124",
#             "CharCode": "CAD",
#             "Nominal": 1,
#             "Name": "Канадский доллар",
#             "Value": 57.5792,
#             "Previous": 57.2321
#         },
#         "QAR": {
#             "ID": "R01355",
#             "NumCode": "634",
#             "CharCode": "QAR",
#             "Nominal": 1,
#             "Name": "Катарский риал",
#             "Value": 21.9054,
#             "Previous": 21.9102
#         },
#         "KGS": {
#             "ID": "R01370",
#             "NumCode": "417",
#             "CharCode": "KGS",
#             "Nominal": 100,
#             "Name": "Сомов",
#             "Value": 91.1786,
#             "Previous": 91.1984
#         },
#         "CNY": {
#             "ID": "R01375",
#             "NumCode": "156",
#             "CharCode": "CNY",
#             "Nominal": 1,
#             "Name": "Юань",
#             "Value": 11.0101,
#             "Previous": 11.0876
#         },
#         "MDL": {
#             "ID": "R01500",
#             "NumCode": "498",
#             "CharCode": "MDL",
#             "Nominal": 10,
#             "Name": "Молдавских леев",
#             "Value": 46.1564,
#             "Previous": 45.8511
#         },
#         "NZD": {
#             "ID": "R01530",
#             "NumCode": "554",
#             "CharCode": "NZD",
#             "Nominal": 1,
#             "Name": "Новозеландский доллар",
#             "Value": 47.2474,
#             "Previous": 47.3414
#         },
#         "NOK": {
#             "ID": "R01535",
#             "NumCode": "578",
#             "CharCode": "NOK",
#             "Nominal": 10,
#             "Name": "Норвежских крон",
#             "Value": 78.6038,
#             "Previous": 77.3145
#         },
#         "PLN": {
#             "ID": "R01565",
#             "NumCode": "985",
#             "CharCode": "PLN",
#             "Nominal": 1,
#             "Name": "Злотый",
#             "Value": 21.2295,
#             "Previous": 21.2947
#         },
#         "RON": {
#             "ID": "R01585F",
#             "NumCode": "946",
#             "CharCode": "RON",
#             "Nominal": 1,
#             "Name": "Румынский лей",
#             "Value": 17.8184,
#             "Previous": 17.8096
#         },
#         "XDR": {
#             "ID": "R01589",
#             "NumCode": "960",
#             "CharCode": "XDR",
#             "Nominal": 1,
#             "Name": "СДР (специальные права заимствования)",
#             "Value": 108.175,
#             "Previous": 107.8133
#         },
#         "SGD": {
#             "ID": "R01625",
#             "NumCode": "702",
#             "CharCode": "SGD",
#             "Nominal": 1,
#             "Name": "Сингапурский доллар",
#             "Value": 61.849,
#             "Previous": 61.7857
#         },
#         "TJS": {
#             "ID": "R01670",
#             "NumCode": "972",
#             "CharCode": "TJS",
#             "Nominal": 10,
#             "Name": "Сомони",
#             "Value": 77.4088,
#             "Previous": 77.3287
#         },
#         "THB": {
#             "ID": "R01675",
#             "NumCode": "764",
#             "CharCode": "THB",
#             "Nominal": 10,
#             "Name": "Батов",
#             "Value": 24.3959,
#             "Previous": 24.3521
#         },
#         "TRY": {
#             "ID": "R01700J",
#             "NumCode": "949",
#             "CharCode": "TRY",
#             "Nominal": 10,
#             "Name": "Турецких лир",
#             "Value": 20.553,
#             "Previous": 20.5518
#         },
#         "TMT": {
#             "ID": "R01710A",
#             "NumCode": "934",
#             "CharCode": "TMT",
#             "Nominal": 1,
#             "Name": "Новый туркменский манат",
#             "Value": 22.7816,
#             "Previous": 22.7866
#         },
#         "UZS": {
#             "ID": "R01717",
#             "NumCode": "860",
#             "CharCode": "UZS",
#             "Nominal": 10000,
#             "Name": "Узбекских сумов",
#             "Value": 61.6294,
#             "Previous": 61.858
#         },
#         "UAH": {
#             "ID": "R01720",
#             "NumCode": "980",
#             "CharCode": "UAH",
#             "Nominal": 10,
#             "Name": "Гривен",
#             "Value": 19.2135,
#             "Previous": 19.2473
#         },
#         "CZK": {
#             "ID": "R01760",
#             "NumCode": "203",
#             "CharCode": "CZK",
#             "Nominal": 10,
#             "Name": "Чешских крон",
#             "Value": 36.1712,
#             "Previous": 36.3058
#         },
#         "SEK": {
#             "ID": "R01770",
#             "NumCode": "752",
#             "CharCode": "SEK",
#             "Nominal": 10,
#             "Name": "Шведских крон",
#             "Value": 83.2392,
#             "Previous": 82.3727
#         },
#         "CHF": {
#             "ID": "R01775",
#             "NumCode": "756",
#             "CharCode": "CHF",
#             "Nominal": 1,
#             "Name": "Швейцарский франк",
#             "Value": 96.509,
#             "Previous": 95.8685
#         },
#         "RSD": {
#             "ID": "R01805F",
#             "NumCode": "941",
#             "CharCode": "RSD",
#             "Nominal": 100,
#             "Name": "Сербских динаров",
#             "Value": 77.0811,
#             "Previous": 77.0706
#         },
#         "ZAR": {
#             "ID": "R01810",
#             "NumCode": "710",
#             "CharCode": "ZAR",
#             "Nominal": 10,
#             "Name": "Рэндов",
#             "Value": 44.4047,
#             "Previous": 44.5871
#         },
#         "KRW": {
#             "ID": "R01815",
#             "NumCode": "410",
#             "CharCode": "KRW",
#             "Nominal": 1000,
#             "Name": "Вон",
#             "Value": 57.4837,
#             "Previous": 57.2691
#         },
#         "JPY": {
#             "ID": "R01820",
#             "NumCode": "392",
#             "CharCode": "JPY",
#             "Nominal": 100,
#             "Name": "Иен",
#             "Value": 55.6231,
#             "Previous": 55.2957
#         }
#     }
# }

# %% [markdown]
# > Как правило, при работе над реальным проектом на этапе получения данных мы уже понимаем, с какими форматами данных нам
# > придётся работать. На предлагаемом для работы ресурсе информация есть как в JSON-формате, так и в XML. По нашему запросу
# > ресурс возвращает информацию в JSON-формате, однако в настоящий момент результат хранится как единая строка. Проверить тип
# > данных полученного ответа можно, воспользовавшись функцией **type()**.
#
# Для того чтобы удобно было работать с полученной информацией, нам необходимо преобразовать строку в словарь.
#
# В объект ответа `Response`  из библиотеки `requests` уже встроен метод `json()` .
#
# Импортируем функцию `pprint()`, применим к полученному ответу метод `json()` и выведем полученный результат на экран:

# %%
from pprint import pprint # Импортируем функцию pprint()
import json # Импортируем модуль json
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран
# Out:
# {'Date': '2025-05-23T11:30:00+03:00',
#  'PreviousDate': '2025-05-22T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2025/05/22/daily_json.js',
#  'Timestamp': '2025-05-22T20:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 21.7163,
#                     'Value': 21.7116},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 20.7118,
#                     'Value': 20.7407},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 51.4566,
#                     'Value': 51.4136},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 46.9135,
#                     'Value': 46.9034},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 45.8374,
#                     'Value': 46.1538},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 14.0864,
#                     'Value': 14.0955},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 26.5525,
#                     'Value': 26.5449},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 57.2321,
#                     'Value': 57.5792},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 95.8685,
#                     'Value': 96.509},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 11.0876,
#                     'Value': 11.0101},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 36.3058,
#                     'Value': 36.1712},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 12.0182,
#                     'Value': 12.1017},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 15.9951,
#                     'Value': 15.9785},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 91.299,
#                     'Value': 90.2004},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 106.6218,
#                     'Value': 107.1409},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 29.1059,
#                     'Value': 29.1038},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгский доллар',
#                     'Nominal': 1,
#                     'NumCode': '344',
#                     'Previous': 10.2025,
#                     'Value': 10.2068},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 22.4303,
#                     'Value': 22.3506},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 48.6121,
#                     'Value': 48.5808},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 93.2188,
#                     'Value': 93.0782},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 55.2957,
#                     'Value': 55.6231},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 91.1984,
#                     'Value': 91.1786},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 57.2691,
#                     'Value': 57.4837},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 15.5892,
#                     'Value': 15.6164},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 45.8511,
#                     'Value': 46.1564},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 77.3145,
#                     'Value': 78.6038},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 47.3414,
#                     'Value': 47.2474},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 21.2947,
#                     'Value': 21.2295},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 21.9102,
#                     'Value': 21.9054},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 17.8096,
#                     'Value': 17.8184},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 77.0706,
#                     'Value': 77.0811},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 82.3727,
#                     'Value': 83.2392},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 61.7857,
#                     'Value': 61.849},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 24.3521,
#                     'Value': 24.3959},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 77.3287,
#                     'Value': 77.4088},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 22.7866,
#                     'Value': 22.7816},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 20.5518,
#                     'Value': 20.553},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 19.2473,
#                     'Value': 19.2135},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 79.753,
#                     'Value': 79.7357},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 61.858,
#                     'Value': 61.6294},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 31.9498,
#                     'Value': 31.9518},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 107.8133,
#                     'Value': 108.175},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 44.5871,
#                     'Value': 44.4047}}}

# %% [markdown]
# Теперь данные находятся в словаре и можно легко получать необходимые значения.
#
# Например, по ключу `Valute` мы можем обратиться к вложенному словарю, который содержит информацию о мировых валютах. Выведем на экран, например, информацию о евро (`EUR`):

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро

print(currencies['Valute']['CZK']['Name'])
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 91.299,
#  'Value': 90.2004}
# Чешских крон
